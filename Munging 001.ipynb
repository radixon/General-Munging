# %%
import numpy as np
import pandas as pd

# %%
owner = pd.read_csv("owner.csv",sep=';')
num_parameters = len(owner.columns)
print("\nNumber of Columns:")
print(num_parameters)

num_records = len(owner)
print("\nNumber of Records:")
print(num_records)
# Out:
# Number of Columns:
# 1
#
# Number of Records:
# 16929

# %%
records = []
records = str(owner.columns)
records
# Out:
# "Index(['ADJFREQ1,ADJFREQ2,ADJFREQ3,AGERULE,ARM2FIX1,ARM2FIX2,ARM2FIX3,BONDFND1,BONDFND2,BONDFND3,BUYDOWN1,BUYDOWN2,BUYDOWN3,BUYDTYP1,BUYDTYP2,BUYDTYP3,CNV2ARM1,CNV2ARM2,CNV2ARM3,CNV2FIX1,CNV2FIX2,CNV2FIX3,DEVLPMNT,DISASTER,DKBENEFT,ELDERLY,FEDGOV,FIX2ARM1,FIX2ARM2,FIX2ARM3,FORCLOS1,FORCLOS2,FORCLOS3,FREQCHG1,FREQCHG2,FREQCHG3,FULAMTZ1,FULAMTZ2,FULAMTZ3,GOVSUB,GULFWAR,HEBORROW,HEOTHFRQ,HEPIFREQ,HHOLDMTG,HISTORIC,HMTGKIND,HOLDMTG1,HOLDMTG2,HOLDMTG3,HOMESTED,HOWACQ,HOWFINCD,HPROPTYPE,IHOLDMTG,IMTGKIND,INDXADJ1,INDXADJ2,INDXADJ3,INLOTFRQ,INLPIFRQ,INLPOD,INSTLOAN,KEEPPMT1,KEEPPMT2,KEEPPMT3,KOREA,LANDTRST,LIVEHERE,LOCALGOV,LOWINCM,LOWRATE,M1APPLY,M1INT,M1OTHPD,M1PMI,M1PRIN,M1PRPINS,M1RETAX,M1RFREAS,M1SAMELN,M1SAMEMG,M2INT,M2OTHPD,M2PRIN,M3INT,M3OTHPD,M3PRIN,MHCONDO,MHPERM,MTGINSR1,MTGINSR2,MTGINSR3,MTGINST1,MTGINST2,MTGINST3,MTGKIND1,MTGKIND2,MTGKIND3,MTGORIG1,MTGORIG2,MTGORIG3,NEGAMTZ1,NEGAMTZ2,NEGAMTZ3,NEWBLDG,NOBENEFT,NONPROF,NOVETS,NUMOWNER,ONDEMAND1,ONDEMAND2,ONDEMAND3,OTHBENFT,OTHCHG1,OTHCHG2,OTHCHG3,OTHFREQ1,OTHFREQ2,OTHFREQ3,OWNBEFOR,OWNLAND,P1HISPAN,P1SEX,P2HISPAN,P2SEX,PIFREQ1,PIFREQ2,PIFREQ3,PINSFRQ1,PINSFRQ2,PINSFRQ3,PLASSMD1,PLASSMD2,PLASSMD3,PMIFREQ1,PMIFREQ2,PMIFREQ3,PMTSTAT1,PMTSTAT2,PMTSTAT3,RATECHG1,RATECHG2,RATECHG3,RESERVES,RESREL,RETXFRQ1,RETXFRQ2,RETXFRQ3,SAMETIME,SENIORNH,STATEGOV,SUBPRIM1,SUBPRIM2,SUBPRIM3,TXRELIEF,VIETNAM,WWII,P1RACE,P2RACE,R_PURPRICE_VALUE,R_VALUE_PER_HU,TOTMORT,WEIGHT,SERVICR1,RECVPMT1,MAINOFC1,ASSMDMM1,ASSMDYR1,BALASSM1,ORIGMM1,ORIGYR1,ORIGTRM1,ORIGAMT1,ORIGVAL1,POINTS1,MTGBAL1,MGBALMM1,MGBALYR1,CURRATE1,TREASYY1,MARGIN1,INITRTE1,RATECAP1,LIFECAP1,NEGCAP1,PIPMT1,INTPMT1,RETXPMT1,PINSPMT1,PMIPMT1,OTHPMT1,JASSMDYR1,JORIGYR1,JMTGKIND1,JHOLDMTG1,JMTGORIG1,JPIPMT1,JRETXPMT1,JPINSPMT1,JPMIPMT1,JOTHPMT1,JPIFREQ1,JSERVICR1,JKEEPPMT1,JRECVPMT1,JMTGINSR1,JSUBPRIM1,JMTGINST1,JNDEMAND1,JORIGTRM1,JORIGAMT1,JCURRATE1,JMGBALYR1,JMGBALMM1,JINTPMT1,JRETXFRQ1,JPINSFRQ1,JPMIFREQ1,JTOTPMT1,JOTHFREQ1,JFULAMTZ1,JMAINOFC1,JINITRTE1,JLIFECAP1,JRATECAP1,JPOINTS1,JORIGVAL1,JMTGBAL1,JPLASSMD1,JBALASSM1,SERVICR2,RECVPMT2,MAINOFC2,ASSMDMM2,ASSMDYR2,BALASSM2,ORIGMM2,ORIGYR2,ORIGTRM2,ORIGAMT2,ORIGVAL2,POINTS2,MTGBAL2,MGBALMM2,MGBALYR2,CURRATE2,TREASYY2,MARGIN2,INITRTE2,RATECAP2,LIFECAP2,NEGCAP2,PIPMT2,INTPMT2,RETXPMT2,PINSPMT2,PMIPMT2,OTHPMT2,JASSMDYR2,JORIGYR2,JMTGKIND2,JHOLDMTG2,JMTGORIG2,JPIPMT2,JRETXPMT2,JPINSPMT2,JPMIPMT2,JOTHPMT2,JPIFREQ2,JSERVICR2,JKEEPPMT2,JRECVPMT2,JMTGINSR2,JSUBPRIM2,JMTGINST2,JNDEMAND2,JORIGTRM2,JORIGAMT2,JCURRATE2,JMGBALYR2,JMGBALMM2,JINTPMT2,JRETXFRQ2,JPINSFRQ2,JPMIFREQ2,JTOTPMT2,JOTHFREQ2,JFULAMTZ2,JMAINOFC2,JINITRTE2,JLIFECAP2,JRATECAP2,JPOINTS2,JORIGVAL2,JMTGBAL2,JPLASSMD2,JBALASSM2,SERVICR3,RECVPMT3,MAINOFC3,ASSMDMM3,ASSMDYR3,BALASSM3,ORIGMM3,ORIGYR3,ORIGTRM3,ORIGAMT3,ORIGVAL3,POINTS3,MTGBAL3,MGBALMM3,MGBALYR3,CURRATE3,TREASYY3,MARGIN3,INITRTE3,RATECAP3,LIFECAP3,NEGCAP3,PIPMT3,INTPMT3,RETXPMT3,PINSPMT3,PMIPMT3,OTHPMT3,JASSMDYR3,JORIGYR3,JMTGKIND3,JHOLDMTG3,JMTGORIG3,JPIPMT3,JRETXPMT3,JPINSPMT3,JPMIPMT3,JOTHPMT3,JPIFREQ3,JSERVICR3,JKEEPPMT3,JRECVPMT3,JMTGINSR3,JSUBPRIM3,JMTGINST3,JNDEMAND3,JORIGTRM3,JORIGAMT3,JCURRATE3,JMGBALYR3,JMGBALMM3,JINTPMT3,JRETXFRQ3,JPINSFRQ3,JPMIFREQ3,JTOTPMT3,JOTHFREQ3,JFULAMTZ3,JMAINOFC3,JINITRTE3,JLIFECAP3,JRATECAP3,JPOINTS3,JORIGVAL3,JMTGBAL3,JPLASSMD3,JBALASSM3,HEHOLDER,HEVALUE,HEBAL,HEBALMM,HEBALYR,HEPOINTS,HERATE,HECAPS,HELTCAPS,HEPIPMT,HEINTPMT,HEOTHPMT,JHMTGKIND,JHHOLDMTG,JEHOLDER,JHEBAL,JHERATE,JHEPIPMT,JEPIFREQ,JEOTHPMT,JEOTHFRQ,JEPOINTS,JHECAPS,JELTCAPS,JEBORROW,INLHOLDR,INLMM,INLYR,INLTERM,INLVALUE,INLBAL,INLBALMM,INLBALYR,INLRATE,INLPIPMT,INLINPMT,INLOTPMT,JINLYR,JIMTGKIND,JIHOLDMTG,JNLHOLDR,JINLTERM,JINLRATE,JNLPIPMT,JNLPIFRQ,JNLOTPMT,JNLOTFRQ,JINLBAL,JNLVALUE,P1AGE,P2AGE,M1LNDTYP,YRACQ,PURPRICE,SOLDHOME,SOLDOTHR,CASH,PENSION,OTHBORRW,INSURNCE,LEASEPUR,GOVSOURC,NONPROFT,PARENTS,OTHDOWN,NODWNPMT,MHVALUE,MHMODLYR,INLAMT,NUMMORT,NUMCTRCT,NUMHE,NUMOTHLN,M1CASHBK,M1REPAIR,M1DEBTS,M1REALST,M1OTHINV,M1EXPENS,M1BUS,M1DIVORC,M1PAYTAX,M1VEHICL,M1PRODCT,M1 ...

# %%
x = records.find(',',0)
print(x)
# Out:
# 16

# %%
parameters = []
y = records.find("A")
while x > -0.5:
    parameters.append(records[y:x-1])
    y = x + 1
    x = records.find(',',y)

# %%
len(parameters)
# Out:
# 521

# %%
parameters[0]
# Out:
# 'ADJFREQ'

# %%
parameters[520]
# Out:
# "MSASTAT'"
